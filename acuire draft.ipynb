# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd


import matplotlib.pyplot as plt
import seaborn as sns

from env import host, user, password

# %%
def get_connection(db, username=user, host=host, password=password):
    '''
    Creates a connection URL
    '''
    return f'mysql+pymysql://{username}:{password}@{host}/{db}'

    
def new_log_data():
    '''
    Returns curriculum log info into a dataframe
    '''
    sql_query = '''  
    SELECT *
    FROM logs
    LEFT OUTER JOIN cohorts
    ON cohorts.id = logs.cohort_id;
    '''
    df = pd.read_sql(sql_query, get_connection('curriculum_logs'))
    return df

# %%
df= new_log_data()

# %%
df
# Out:
#               date      time  \
# 0       2018-01-26  09:55:03
# 1       2018-01-26  09:56:02
# 2       2018-01-26  09:56:05
# 3       2018-01-26  09:56:06
# 4       2018-01-26  09:56:24
# ...            ...       ...
# 900218  2021-04-21  16:41:51
# 900219  2021-04-21  16:42:02
# 900220  2021-04-21  16:42:09
# 900221  2021-04-21  16:44:37
# 900222  2021-04-21  16:44:39
#
#                                                     path  user_id  cohort_id  \
# 0                                                      /        1        8.0
# 1                                                java-ii        1        8.0
# 2                    java-ii/object-oriented-programming        1        8.0
# 3                     slides/object_oriented_programming        1        8.0
# 4                              javascript-i/conditionals        2       22.0
# ...                                                  ...      ...        ...
# 900218                              jquery/personal-site       64       28.0
# 900219                                 jquery/mapbox-api       64       28.0
# 900220                           jquery/ajax/weather-map       64       28.0
# 900221  anomaly-detection/discrete-probabilistic-methods      744       28.0
# 900222                                 jquery/mapbox-api       64       28.0
#
#                    ip    id     name     slack  start_date    end_date  \
# 0        97.105.19.61   8.0  Hampton  #hampton  2015-09-22  2016-02-06
# 1        97.105.19.61   8.0  Hampton  #hampton  2015-09-22  2016-02-06
# 2        97.105.19.61   8.0  Hampton  #hampton  2015-09-22  2016-02-06
# 3        97.105.19.61   8.0  Hampton  #hampton  2015-09-22  2016-02-06
# 4        97.105.19.61  22.0    Teddy    #teddy  2018-01-08  2018-05-17
# ...               ...   ...      ...       ...         ...         ...
# 900218  71.150.217.33  28.0    Staff         #  2014-02-04  2014-02-04
# 900219  71.150.217.33  28.0    Staff         #  2014-02-04  2014-02-04
# 900220  71.150.217.33  28.0    Staff         #  2014-02-04  2014-02-04
# 900221  24.160.137.86  28.0    Staff         #  2014-02-04  2014-02-04
# 900222  71.150.217.33  28.0    Staff         #  2014-02-04  2014-02-04
#
#                  created_at           updated_at deleted_at  program_id
# 0       2016-06-14 19:52:26  2016-06-14 19:52:26       None         1.0
# 1       2016-06-14 19:52:26  2016-06-14 19:52:26       None         1.0
# 2       2016-06-14 19:52:26  2016-06-14 19:52:26       None         1.0
# 3       2016-06-14 19:52:26  2016-06-14 19:52:26       None         1.0
# 4       2018-01-08 13:59:10  2018-01-08 13:59:10       None         2.0
# ...                     ...                  ...        ...         ...
# 900218  2018-12-06 17:04:19  2018-12-06 17:04:19       None         2.0
# 900219  2018-12-06 17:04:19  2018-12-06 17:04:19       None         2.0
# 900220  2018-12-06 17:04:19  2018-12-06 17:04:19       None         2.0
# 900221  2018-12-06 17:04:19  2018-12-06 17:04:19       None         2.0
# 900222  2018-12-06 17:04:19  2018-12-06 17:04:19       None         2.0
#
# [900223 rows x 15 columns]

# %%
df.program_id.value_counts()
# Out:
# 2.0    713365
# 3.0    103412
# 1.0     30548
# 4.0         5
# Name: program_id, dtype: int64

# %%
#Creating english names for the different program_ids 
conditions = [(df.program_id == 1), (df.program_id == 2), (df.program_id == 3), (df.program_id == 4)]
actions = ['php','java', 'ds','fe']
df['program'] = np.select(conditions,actions,default='Other')

# %%
program1= df[df.program_id == 1]
program2 = df[df.program_id == 2]
program3 = df[df.program_id == 3]
program4 = df[df.program_id == 4]

# %%
program1.path.value_counts(normalize=True).sort_values().nlargest(3)
# Out:
# /               0.055028
# index.html      0.033095
# javascript-i    0.024093
# Name: path, dtype: float64

# %%
program2.path.value_counts(normalize=True).sort_values().nlargest(3)
# Out:
# /               0.050204
# javascript-i    0.024471
# toc             0.024431
# Name: path, dtype: float64

# %%
program3.path.value_counts(normalize=True).sort_values().nlargest(3)
# Out:
# /                           0.080823
# search/search_index.json    0.021303
# classification/overview     0.017261
# Name: path, dtype: float64

# %%
program4.path.value_counts(normalize=True).sort_values().nlargest(3)
# Out:
# content/html-css                               0.4
# /                                              0.2
# content/html-css/gitbook/images/favicon.ico    0.2
# Name: path, dtype: float64

# %%
d = program3.groupby(['name'])

# %%
d.head()
# Out:
#               date      time                                      path  \
# 326053  2019-08-20  09:39:58                                         /
# 326054  2019-08-20  09:39:59                                         /
# 326055  2019-08-20  09:39:59                                         /
# 326056  2019-08-20  09:40:02                                         /
# 326057  2019-08-20  09:40:08                                         /
# 445311  2020-02-03  15:39:34                                     login
# 445314  2020-02-03  15:39:35                                         /
# 445315  2020-02-03  15:39:37                                         /
# 445316  2020-02-03  15:39:37                                     login
# 445317  2020-02-03  15:39:43                                         /
# 597038  2020-07-13  14:34:44                                         /
# 597043  2020-07-13  14:37:22                                         /
# 597056  2020-07-13  14:38:28                                         /
# 597057  2020-07-13  14:39:21            13-advanced-topics/1-tidy-data
# 597058  2020-07-13  14:39:36  1-fundamentals/1.1-intro-to-data-science
# 755214  2020-12-08  10:49:37                                         /
# 755216  2020-12-08  10:49:39                                         /
# 755217  2020-12-08  10:49:40                                         /
# 755218  2020-12-08  10:49:52                                         /
# 755220  2020-12-08  10:50:16                                         /
# 847090  2021-03-15  15:22:48                                         /
# 847092  2021-03-15  15:23:17                                         /
# 847094  2021-03-15  15:23:33                                         /
# 847095  2021-03-15  15:23:48                                         /
# 847096  2021-03-15  15:24:05        fundamentals/intro-to-data-science
#
#         user_id  cohort_id               ip     id      name      slack  \
# 326053      466       34.0     97.105.19.58   34.0     Bayes          #
# 326054      467       34.0     97.105.19.58   34.0     Bayes          #
# 326055      468       34.0     97.105.19.58   34.0     Bayes          #
# 326056      469       34.0     97.105.19.58   34.0     Bayes          #
# 326057      470       34.0     97.105.19.58   34.0     Bayes          #
# 445311      575       55.0     97.105.19.58   55.0     Curie     #curie
# 445314      576       55.0     97.105.19.58   55.0     Curie     #curie
# 445315      577       55.0     97.105.19.58   55.0     Curie     #curie
# 445316      575       55.0     97.105.19.58   55.0     Curie     #curie
# 445317      578       55.0     97.105.19.58   55.0     Curie     #curie
# 597038      678       59.0    76.201.20.193   59.0    Darden    #darden
# 597043      679       59.0    24.28.146.155   59.0    Darden    #darden
# 597056      680       59.0    136.50.56.155   59.0    Darden    #darden
# 597057      679       59.0    24.28.146.155   59.0    Darden    #darden
# 597058      679       59.0    24.28.146.155   59.0    Darden    #darden
# 755214      835      133.0    173.173.109.5  133.0    Easley    #easley
# 847096  2021-03-15  2021-09-03  2021-03-15 18:18:20  2021-03-15 18:18:20
#
#        deleted_at  program_id program
# 326053       None         3.0      ds
# 326054       None         3.0      ds
# 326055       None         3.0      ds
# 326056       None         3.0      ds
# 326057       None         3.0      ds
# 445311       None         3.0      ds
# 445314       None         3.0      ds
# 445315       None         3.0      ds
# 445316       None         3.0      ds
# 445317       None         3.0      ds
# 597038       None         3.0      ds
# 597043       None         3.0      ds
# 597056       None         3.0      ds
# 597057       None         3.0      ds
# 597058       None         3.0      ds
# 755214       None         3.0      ds
# 755216       None         3.0      ds
# 755217       None         3.0      ds
# 755218       None         3.0      ds
# 755220       None         3.0      ds
# 847090       None         3.0      ds
# 847092       None         3.0      ds
# 847094       None         3.0      ds
# 847095       None         3.0      ds
# 847096       None         3.0      ds

# %%
d2= d.apply(lambda x: x.path.value_counts(normalize=True).sort_values(ascending = False))

# %%
d2
# Out:
# name
# Bayes     /                                             0.074120
#           1-fundamentals/modern-data-scientist.jpg      0.024493
#           1-fundamentals/AI-ML-DL-timeline.jpg          0.024418
#           1-fundamentals/1.1-intro-to-data-science      0.024116
#           search/search_index.json                      0.022157
#                                                           ...
# Florence  fundamentals/spreadsheets-overview            0.000117
#           environment-setup                             0.000117
#           joins                                         0.000117
#           distributed-ml/spark-execution-diagram.svg    0.000117
#           ml-methodologies-drawing.jpg                  0.000117
# Name: path, Length: 1763, dtype: float64

# %%
d2.groupby('name').head(5)
# Out:
# name
# Bayes     /                                                                0.074120
#           1-fundamentals/modern-data-scientist.jpg                         0.024493
#           1-fundamentals/AI-ML-DL-timeline.jpg                             0.024418
#           1-fundamentals/1.1-intro-to-data-science                         0.024116
#           search/search_index.json                                         0.022157
# Curie     /                                                                0.079329
#           6-regression/1-overview                                          0.027571
#           search/search_index.json                                         0.024929
#           1-fundamentals/modern-data-scientist.jpg                         0.021639
#           1-fundamentals/AI-ML-DL-timeline.jpg                             0.021547
# Darden    /                                                                0.093081
#           classification/overview                                          0.034640
#           classification/scale_features_or_not.svg                         0.029455
#           sql/mysql-overview                                               0.024176
#           search/search_index.json                                         0.020740
# Easley    /                                                                0.075773
#           classification/scale_features_or_not.svg                         0.031464
#           classification/overview                                          0.030241
#           classification/classical_programming_vs_machine_learning.jpeg    0.029358
#           fundamentals/AI-ML-DL-timeline.jpg                               0.025892
# Florence  fundamentals/modern-data-scientist.jpg                           0.073231
#           fundamentals/AI-ML-DL-timeline.jpg                               0.072880
#           fundamentals/intro-to-data-science                               0.071829
#           /                                                                0.068208
#           python/data-types-and-variables                                  0.030133
# Name: path, dtype: float64

# %%
sns.set_style('darkgrid')

x = 
y = [1, 5, 3]

sns.barplot(x, y)
plt.show()
